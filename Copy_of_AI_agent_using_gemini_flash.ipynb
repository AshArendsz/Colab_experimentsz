# %% [markdown]
# <a href="https://colab.research.google.com/github/AshArendsz/Colab_experimentsz/blob/main/Copy_of_AI_agent_using_gemini_flash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-generativeai

# %%
from google.colab import userdata
userdata.get('Gem01')
# Out:
# 'AIzaSyC6RoAi7pZbISpmbWfH2fYR0JY5J6As3t0'

# %%
import google.generativeai as genai
import os

# 🔑 Set your Gemini API Key
# Option 1: Environment variable (recommended)
# export GOOGLE_API_KEY="your_api_key_here"

# Option 2: Direct assignment (not recommended for production)
# GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY") or "YOUR_API_KEY_HERE"
GOOGLE_API_KEY = userdata.get("Gem01")

genai.configure(api_key=GOOGLE_API_KEY)

# %%
MODEL_NAME = "gemini-2.5-flash"

SYSTEM_PROMPT = """
You are a helpful AI agent.
Answer clearly and concisely.
"""

class FastGeminiAgent:
    def __init__(self):
        self.model = genai.GenerativeModel(
            model_name=MODEL_NAME,
            system_instruction=SYSTEM_PROMPT
        )

    def generate(self, user_input):
        response = self.model.generate_content(
            user_input,
            generation_config={
                "temperature": 0.5,
                "max_output_tokens": 300
            }
        )
        return response.text.strip()


def run_agent():
    if GOOGLE_API_KEY == "YOUR_API_KEY_HERE":
        print("Error: Please set your Gemini API key in the previous cell (cell Umtu7hPNlhl8).")
        print("You can get an API key from https://aistudio.google.com/app/apikey")
        return

    agent = FastGeminiAgent()
    print("⚡ Fast AI Agent (Gemini). Type 'quit' to exit.\n")

    while True:
        user_input = input("You: ")
        if user_input.lower() in {"quit", "exit"}:
            print("Agent: Goodbye 👋")
            break

        reply = agent.generate(user_input)
        print("Agent:", reply, "\n")


if __name__ == "__main__":
    run_agent()
# Out:
# ⚡ Fast AI Agent (Gemini). Type 'quit' to exit.
#
# You: testing
# Agent: Hello! How can I help you today?
#
# You: yes
# Agent: Yes? How can I help you today?
#
# You: who are you?
# Agent: I am a large language model, trained by Google.
#
# You: nice to meet you
# Agent: Nice to meet you too! I'm an AI assistant, ready to help. How can I assist you today?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2815982515.py in <cell line: 0>()
#      44
#      45 if __name__ == "__main__":
# ---> 46     run_agent()
#
# /tmp/ipython-input-2815982515.py in run_agent()
#      34
#      35     while True:
# ---> 36         user_input = input("You: ")
#      37         if user_input.lower() in {"quit", "exit"}:
#      38             print("Agent: Goodbye 👋")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...
